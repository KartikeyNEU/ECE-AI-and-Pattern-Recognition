# %% [markdown]
# # Problem 1.2
# Part A

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import pandas as pd

# %%
# Generate 10,000 points 
# full dataset (10k samples) stored in array 'dataset'. data0 and data1 are the preclassified data. 
mean1 = (-1, 1, -1)
cov1 = np.array([[2, -0.5, 0.3], [-0.5, 1, -0.5], [0.3, -0.5, 1]])
rng = np.random.default_rng()
y1 = rng.multivariate_normal(mean1, cov1, size=3000)

mean2 = (1, 1, 1)
cov2 = np.array([[1, 0.3, -0.2], [0.3, 2, 0.3], [-0.2, 0.3, 1]])
rng = np.random.default_rng()
y2 = rng.multivariate_normal(mean2, cov2, size=3000)

mean3 = (1, 1, 1)
cov3 = np.array([[1, 0.3, -0.2], [2, 0.3, 0], [ 0.3, 1, 0]])
rng = np.random.default_rng()
y3 = rng.multivariate_normal(mean3, cov3, size=2000)

mean4 = (1, 1, 1)
cov4 = np.array([[1, 0.3, -0.2], [0.3, 2, 0.3], [-0.2, 0.3, 1]])
rng = np.random.default_rng()
y4 = rng.multivariate_normal(mean4, cov4, size=2000)

Dataset = np.concatenate((data1,data2,data3,data4))
# Out:
# /var/folders/w7/czd3jztj7jvdkz_2d4cb5_gm0000gn/T/ipykernel_39003/2700017004.py:18: RuntimeWarning: covariance is not positive-semidefinite.
#   y3 = rng.multivariate_normal(mean3, cov3, size=2000)

# %%
 
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(y1[:,0], y1[:,1], y1[:,2], marker = '.')
ax.scatter3D(y2[:,0], y2[:,1], y2[:,2], marker = 'o')
ax.scatter3D(y3[:,0], y3[:,1], y3[:,2], marker = 'x')
ax.scatter3D(y4[:,0], y4[:,1], y4[:,2], marker = 's')
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()
